# %%
 # %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
combine_data = city_data.merge(ride_data,on='city')

# Display the data table for preview
combine_data
# Out:
#                  city  driver_count   type                 date   fare  \
# 0         Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1         Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2         Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3         Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4         Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 5         Richardfort            38  Urban  2018-04-21 03:44:04   9.54
# 6         Richardfort            38  Urban  2018-02-03 00:14:26  29.04
# 7         Richardfort            38  Urban  2018-02-08 15:50:12  16.55
# 8         Richardfort            38  Urban  2018-04-03 15:07:34  40.77
# 9         Richardfort            38  Urban  2018-02-19 14:09:20  27.11
# 10        Richardfort            38  Urban  2018-04-22 03:06:56  39.74
# 11        Richardfort            38  Urban  2018-01-31 14:51:01  43.92
# ...

# %%
reduced_df = combine_data[['city','type']]
reduced_df
count_df = reduced_df['city'].value_counts()
count_df
# Out:
# /Users/miiinaa223/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/api.py:107: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
#                       city_counts   type
# West Angela                  39.0    NaN
# South Karenland              38.0    NaN
# North Jason                  35.0    NaN
# Port Frank                   33.0    NaN
# Liumouth                     33.0    NaN
# South Phillip                31.0    NaN
# South Michelleport           31.0    NaN
# South Evanton                31.0    NaN
# West Robert                  31.0    NaN
# West Anthony                 30.0    NaN
# Royland                      30.0    NaN
# North Jasmine                30.0    NaN
# New Kimberlyborough          30.0    NaN
# Justinberg                   30.0    NaN
# East Kaylahaven              29.0    NaN
# Richardfort                  28.0    NaN
# ...

# %%
# Obtain the x and y coordinates for each of the three city types
rides_count = combine_data['city'].value_counts()
rides_df = pd.DataFrame(rides_count)
rides_df
#2 Sum fare
sum_fare = combine_data['fare'].sum()
#3 ave fare using #2
rides_df['ave_fare'] = sum_fare / rides_count
rides_df
#city_group = combine_data.groupby('city','type')
#rides_df['ave_purchase'] = total_purchase / rides_count
#rides_df
# Out:
#                       city      ave_fare
# West Angela             39   1629.195897
# South Karenland         38   1672.069474
# North Jason             35   1815.389714
# Port Frank              33   1925.413333
# Liumouth                33   1925.413333
# South Michelleport      31   2049.633548
# South Evanton           31   2049.633548
# West Robert             31   2049.633548
# South Phillip           31   2049.633548
# West Anthony            30   2117.954667
# North Jasmine           30   2117.954667
# New Kimberlyborough     30   2117.954667
# Justinberg              30   2117.954667
# Royland                 30   2117.954667
# East Kaylahaven         29   2190.987586
# Karenside               28   2269.237143
# Loganberg               28   2269.237143
# Hurleymouth             28   2269.237143
# Richardfort             28   2269.237143
# West Heidi              28   2269.237143
# Josephside              27   2353.282963
# Carriemouth             27   2353.282963
# ...

# %%
# Build the scatter plots for each city types
#rides_df.plot(kind='scatter',x='city',y='ave_purchase')

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# Show plot
plt.show()

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()
